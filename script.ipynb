-- %% [markdown]
-- # [Nomenclature]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Nomenclature]    Script Date: 10.12.2023 15:46:49 ******/
CREATE DATABASE [Nomenclature]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Nomenclature', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Nomenclature.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Nomenclature_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\Nomenclature_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [Nomenclature] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Nomenclature].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Nomenclature] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Nomenclature] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Nomenclature] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Nomenclature] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Nomenclature] SET ARITHABORT OFF 
GO
ALTER DATABASE [Nomenclature] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Nomenclature] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Nomenclature] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Nomenclature] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Nomenclature] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Nomenclature] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Nomenclature] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Nomenclature] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Nomenclature] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Nomenclature] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Nomenclature] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Nomenclature] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Nomenclature] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Nomenclature] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Nomenclature] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Nomenclature] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Nomenclature] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Nomenclature] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Nomenclature] SET  MULTI_USER 
GO
ALTER DATABASE [Nomenclature] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Nomenclature] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Nomenclature] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Nomenclature] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Nomenclature] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Nomenclature] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Nomenclature] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Hierarchy]

-- %%
USE [Nomenclature]
GO

-- %%
/****** Object:  Table [dbo].[Hierarchy]    Script Date: 10.12.2023 15:46:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Hierarchy](
	[idHierarchy] [int] IDENTITY(1,1) NOT NULL,
	[idParent] [int] NULL,
	[idChild] [int] NULL,
	[Quantity] [int] NULL,
 CONSTRAINT [PK__Hierarch__CB83FA53E273969B] PRIMARY KEY CLUSTERED 
(
	[idHierarchy] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Materials]

-- %%
/****** Object:  Table [dbo].[Materials]    Script Date: 10.12.2023 15:46:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Materials](
	[idMaterial] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](max) NULL,
	[DrawingNumber] [nvarchar](max) NULL,
	[idType] [int] NULL,
 CONSTRAINT [PK__Material__6AC7E3EB7402E84F] PRIMARY KEY CLUSTERED 
(
	[idMaterial] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Movement]

-- %%
/****** Object:  Table [dbo].[Movement]    Script Date: 10.12.2023 15:46:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Movement](
	[idMovement] [int] IDENTITY(1,1) NOT NULL,
	[idWarehouse] [int] NULL,
	[idComposition] [int] NULL,
	[idUser] [int] NULL,
	[PartOfQuantity] [int] NULL,
	[ArrivalOrExpenditure] [bit] NULL,
 CONSTRAINT [PK__Movement__5B3BB2F5EB4BEEDE] PRIMARY KEY CLUSTERED 
(
	[idMovement] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Storage]

-- %%
/****** Object:  Table [dbo].[Storage]    Script Date: 10.12.2023 15:46:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Storage](
	[idStorage] [int] IDENTITY(1,1) NOT NULL,
	[idWarehouse] [int] NULL,
	[idMaterial] [int] NULL,
	[Quantity] [int] NULL,
 CONSTRAINT [PK__Storage__17180CEB521ADACE] PRIMARY KEY CLUSTERED 
(
	[idStorage] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Types]

-- %%
/****** Object:  Table [dbo].[Types]    Script Date: 10.12.2023 15:46:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Types](
	[idType] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](max) NULL,
 CONSTRAINT [PK__Types__4BB98BC60DFBB081] PRIMARY KEY CLUSTERED 
(
	[idType] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Warehouses]

-- %%
/****** Object:  Table [dbo].[Warehouses]    Script Date: 10.12.2023 15:46:49 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Warehouses](
	[idWarehouse] [int] IDENTITY(1,1) NOT NULL,
	[Name] [nvarchar](max) NULL,
	[Address] [nvarchar](max) NULL,
 CONSTRAINT [PK__Warehous__4E557D38FB7E1B40] PRIMARY KEY CLUSTERED 
(
	[idWarehouse] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Hierarchy__idChi__44FF419A]

-- %%
ALTER TABLE [dbo].[Hierarchy]  WITH CHECK ADD  CONSTRAINT [FK__Hierarchy__idChi__44FF419A] FOREIGN KEY([idChild])
REFERENCES [dbo].[Materials] ([idMaterial])
GO
ALTER TABLE [dbo].[Hierarchy] CHECK CONSTRAINT [FK__Hierarchy__idChi__44FF419A]
GO

-- %% [markdown]
-- # [FK__Hierarchy__idPar__440B1D61]

-- %%
ALTER TABLE [dbo].[Hierarchy]  WITH CHECK ADD  CONSTRAINT [FK__Hierarchy__idPar__440B1D61] FOREIGN KEY([idParent])
REFERENCES [dbo].[Materials] ([idMaterial])
GO
ALTER TABLE [dbo].[Hierarchy] CHECK CONSTRAINT [FK__Hierarchy__idPar__440B1D61]
GO

-- %% [markdown]
-- # [FK__Materials__idTyp__3B75D760]

-- %%
ALTER TABLE [dbo].[Materials]  WITH CHECK ADD  CONSTRAINT [FK__Materials__idTyp__3B75D760] FOREIGN KEY([idType])
REFERENCES [dbo].[Types] ([idType])
GO
ALTER TABLE [dbo].[Materials] CHECK CONSTRAINT [FK__Materials__idTyp__3B75D760]
GO

-- %% [markdown]
-- # [FK__Movement__idWare__47DBAE45]

-- %%
ALTER TABLE [dbo].[Movement]  WITH CHECK ADD  CONSTRAINT [FK__Movement__idWare__47DBAE45] FOREIGN KEY([idWarehouse])
REFERENCES [dbo].[Warehouses] ([idWarehouse])
GO
ALTER TABLE [dbo].[Movement] CHECK CONSTRAINT [FK__Movement__idWare__47DBAE45]
GO

-- %% [markdown]
-- # [FK__Storage__idMater__412EB0B6]

-- %%
ALTER TABLE [dbo].[Storage]  WITH CHECK ADD  CONSTRAINT [FK__Storage__idMater__412EB0B6] FOREIGN KEY([idMaterial])
REFERENCES [dbo].[Materials] ([idMaterial])
GO
ALTER TABLE [dbo].[Storage] CHECK CONSTRAINT [FK__Storage__idMater__412EB0B6]
GO

-- %% [markdown]
-- # [FK__Storage__idWareh__403A8C7D]

-- %%
ALTER TABLE [dbo].[Storage]  WITH CHECK ADD  CONSTRAINT [FK__Storage__idWareh__403A8C7D] FOREIGN KEY([idWarehouse])
REFERENCES [dbo].[Warehouses] ([idWarehouse])
GO
ALTER TABLE [dbo].[Storage] CHECK CONSTRAINT [FK__Storage__idWareh__403A8C7D]
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_4222D4EF]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_4222D4EF]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000002_4222D4EF] ON [dbo].[Hierarchy]([idParent]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_4222D4EF]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_4222D4EF]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000003_4222D4EF] ON [dbo].[Hierarchy]([idChild]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__Hierarch__CB83FA53E273969B]

-- %%
/****** Object:  Statistic [PK__Hierarch__CB83FA53E273969B]    Script Date: 10.12.2023 15:46:49 ******/
UPDATE STATISTICS [dbo].[Hierarchy]([PK__Hierarch__CB83FA53E273969B]) WITH STATS_STREAM = ..., ROWCOUNT = 17, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_398D8EEE]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_398D8EEE]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000002_398D8EEE] ON [dbo].[Materials]([Name]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_398D8EEE]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_398D8EEE]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000003_398D8EEE] ON [dbo].[Materials]([DrawingNumber]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__Material__6AC7E3EB7402E84F]

-- %%
/****** Object:  Statistic [PK__Material__6AC7E3EB7402E84F]    Script Date: 10.12.2023 15:46:49 ******/
UPDATE STATISTICS [dbo].[Materials]([PK__Material__6AC7E3EB7402E84F]) WITH STATS_STREAM = ..., ROWCOUNT = 12, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_45F365D3]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_45F365D3]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000002_45F365D3] ON [dbo].[Movement]([idWarehouse]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_45F365D3]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_45F365D3]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000003_45F365D3] ON [dbo].[Movement]([idComposition]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000006_45F365D3]

-- %%
/****** Object:  Statistic [_WA_Sys_00000006_45F365D3]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000006_45F365D3] ON [dbo].[Movement]([ArrivalOrExpenditure]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__Movement__5B3BB2F5EB4BEEDE]

-- %%
/****** Object:  Statistic [PK__Movement__5B3BB2F5EB4BEEDE]    Script Date: 10.12.2023 15:46:49 ******/
UPDATE STATISTICS [dbo].[Movement]([PK__Movement__5B3BB2F5EB4BEEDE]) WITH STATS_STREAM = ..., ROWCOUNT = 13, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_3E52440B]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_3E52440B]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000002_3E52440B] ON [dbo].[Storage]([idWarehouse]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_3E52440B]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_3E52440B]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000003_3E52440B] ON [dbo].[Storage]([idMaterial]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000004_3E52440B]

-- %%
/****** Object:  Statistic [_WA_Sys_00000004_3E52440B]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000004_3E52440B] ON [dbo].[Storage]([Quantity]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__Storage__17180CEB521ADACE]

-- %%
/****** Object:  Statistic [PK__Storage__17180CEB521ADACE]    Script Date: 10.12.2023 15:46:49 ******/
UPDATE STATISTICS [dbo].[Storage]([PK__Storage__17180CEB521ADACE]) WITH STATS_STREAM = ..., ROWCOUNT = 11, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [PK__Types__4BB98BC60DFBB081]

-- %%
/****** Object:  Statistic [PK__Types__4BB98BC60DFBB081]    Script Date: 10.12.2023 15:46:49 ******/
UPDATE STATISTICS [dbo].[Types]([PK__Types__4BB98BC60DFBB081]) WITH STATS_STREAM = ..., ROWCOUNT = 4, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_3C69FB99]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_3C69FB99]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000002_3C69FB99] ON [dbo].[Warehouses]([Name]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_3C69FB99]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_3C69FB99]    Script Date: 10.12.2023 15:46:49 ******/
CREATE STATISTICS [_WA_Sys_00000003_3C69FB99] ON [dbo].[Warehouses]([Address]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__Warehous__4E557D38FB7E1B40]

-- %%
/****** Object:  Statistic [PK__Warehous__4E557D38FB7E1B40]    Script Date: 10.12.2023 15:46:49 ******/
UPDATE STATISTICS [dbo].[Warehouses]([PK__Warehous__4E557D38FB7E1B40]) WITH STATS_STREAM = ..., ROWCOUNT = 5, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [Nomenclature]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Nomenclature] SET  READ_WRITE 
GO
