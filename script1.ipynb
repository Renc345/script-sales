-- %% [markdown]
-- # [SalesOfMaterial]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [SalesOfMaterial]    Script Date: 10.12.2023 15:48:10 ******/
CREATE DATABASE [SalesOfMaterial]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'SalesOfMaterial', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\SalesOfMaterial.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'SalesOfMaterial_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\SalesOfMaterial_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [SalesOfMaterial] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [SalesOfMaterial].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [SalesOfMaterial] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET ARITHABORT OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [SalesOfMaterial] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [SalesOfMaterial] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [SalesOfMaterial] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET  ENABLE_BROKER 
GO
ALTER DATABASE [SalesOfMaterial] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [SalesOfMaterial] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [SalesOfMaterial] SET  MULTI_USER 
GO
ALTER DATABASE [SalesOfMaterial] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [SalesOfMaterial] SET DB_CHAINING OFF 
GO
ALTER DATABASE [SalesOfMaterial] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [SalesOfMaterial] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [SalesOfMaterial] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [SalesOfMaterial] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [SalesOfMaterial] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Employee]

-- %%
USE [SalesOfMaterial]
GO

-- %%
/****** Object:  Table [dbo].[Employee]    Script Date: 10.12.2023 15:48:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employee](
	[IdEmployee] [int] IDENTITY(1,1) NOT NULL,
	[FIO] [nvarchar](max) NULL,
	[Login_Employee] [nvarchar](max) NULL,
	[Password_Employee] [nvarchar](max) NULL,
	[IdTypesEmployee] [int] NULL,
 CONSTRAINT [PK__Employee__51C8DD7A717A401D] PRIMARY KEY CLUSTERED 
(
	[IdEmployee] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ExpenseComposition]

-- %%
/****** Object:  Table [dbo].[ExpenseComposition]    Script Date: 10.12.2023 15:48:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ExpenseComposition](
	[IdExpenseComposition] [int] IDENTITY(1,1) NOT NULL,
	[IdExpenseIvoices] [int] NULL,
	[IdMaterial] [int] NULL,
	[Quantity] [int] NULL,
	[Price] [float] NULL,
 CONSTRAINT [PK__ExpenseC__AF91D0E1D8CFDC39] PRIMARY KEY CLUSTERED 
(
	[IdExpenseComposition] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ExpenseIvoices]

-- %%
/****** Object:  Table [dbo].[ExpenseIvoices]    Script Date: 10.12.2023 15:48:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ExpenseIvoices](
	[IdExpenseIvoices] [int] IDENTITY(1,1) NOT NULL,
	[IdСounterparties] [int] NULL,
	[IdEmployee] [int] NULL,
	[Date_Transfer] [date] NULL,
	[DistributedInvoice] [bit] NULL,
 CONSTRAINT [PK__ExpenseI__17193BDF5EAB38DD] PRIMARY KEY CLUSTERED 
(
	[IdExpenseIvoices] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TypesEmployee]

-- %%
/****** Object:  Table [dbo].[TypesEmployee]    Script Date: 10.12.2023 15:48:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TypesEmployee](
	[IdTypesEmployee] [int] IDENTITY(1,1) NOT NULL,
	[Nazv_type] [nvarchar](max) NULL,
 CONSTRAINT [PK__TypesEmp__168EF03C2C9D8F19] PRIMARY KEY CLUSTERED 
(
	[IdTypesEmployee] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Сounterparties]

-- %%
/****** Object:  Table [dbo].[Сounterparties]    Script Date: 10.12.2023 15:48:10 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Сounterparties](
	[IdСounterparties] [int] IDENTITY(1,1) NOT NULL,
	[Nazv_Сounterparties] [nvarchar](max) NULL,
	[INN] [nvarchar](12) NULL,
	[Adress_Сounterparties] [nvarchar](max) NULL,
 CONSTRAINT [PK__Сounterp__E5F6AB5E0218DA8B] PRIMARY KEY CLUSTERED 
(
	[IdСounterparties] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Employee__IdType__38996AB5]

-- %%
ALTER TABLE [dbo].[Employee]  WITH CHECK ADD  CONSTRAINT [FK__Employee__IdType__38996AB5] FOREIGN KEY([IdTypesEmployee])
REFERENCES [dbo].[TypesEmployee] ([IdTypesEmployee])
GO
ALTER TABLE [dbo].[Employee] CHECK CONSTRAINT [FK__Employee__IdType__38996AB5]
GO

-- %% [markdown]
-- # [FK__ExpenseCo__IdExp__412EB0B6]

-- %%
ALTER TABLE [dbo].[ExpenseComposition]  WITH CHECK ADD  CONSTRAINT [FK__ExpenseCo__IdExp__412EB0B6] FOREIGN KEY([IdExpenseIvoices])
REFERENCES [dbo].[ExpenseIvoices] ([IdExpenseIvoices])
GO
ALTER TABLE [dbo].[ExpenseComposition] CHECK CONSTRAINT [FK__ExpenseCo__IdExp__412EB0B6]
GO

-- %% [markdown]
-- # [FK__ExpenseIv__IdEmp__3E52440B]

-- %%
ALTER TABLE [dbo].[ExpenseIvoices]  WITH CHECK ADD  CONSTRAINT [FK__ExpenseIv__IdEmp__3E52440B] FOREIGN KEY([IdEmployee])
REFERENCES [dbo].[Employee] ([IdEmployee])
GO
ALTER TABLE [dbo].[ExpenseIvoices] CHECK CONSTRAINT [FK__ExpenseIv__IdEmp__3E52440B]
GO

-- %% [markdown]
-- # [FK__ExpenseIv__IdСou__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[ExpenseIvoices]  WITH CHECK ADD  CONSTRAINT [FK__ExpenseIv__IdСou__3D5E1FD2] FOREIGN KEY([IdСounterparties])
REFERENCES [dbo].[Сounterparties] ([IdСounterparties])
GO
ALTER TABLE [dbo].[ExpenseIvoices] CHECK CONSTRAINT [FK__ExpenseIv__IdСou__3D5E1FD2]
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_36B12243]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_36B12243]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000003_36B12243] ON [dbo].[Employee]([Login_Employee]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000004_36B12243]

-- %%
/****** Object:  Statistic [_WA_Sys_00000004_36B12243]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000004_36B12243] ON [dbo].[Employee]([Password_Employee]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000005_36B12243]

-- %%
/****** Object:  Statistic [_WA_Sys_00000005_36B12243]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000005_36B12243] ON [dbo].[Employee]([IdTypesEmployee]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__Employee__51C8DD7A717A401D]

-- %%
/****** Object:  Statistic [PK__Employee__51C8DD7A717A401D]    Script Date: 10.12.2023 15:48:10 ******/
UPDATE STATISTICS [dbo].[Employee]([PK__Employee__51C8DD7A717A401D]) WITH STATS_STREAM = ..., ROWCOUNT = 4, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_3F466844]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_3F466844]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000002_3F466844] ON [dbo].[ExpenseComposition]([IdExpenseIvoices]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_3F466844]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_3F466844]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000003_3F466844] ON [dbo].[ExpenseComposition]([IdMaterial]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__ExpenseC__AF91D0E1D8CFDC39]

-- %%
/****** Object:  Statistic [PK__ExpenseC__AF91D0E1D8CFDC39]    Script Date: 10.12.2023 15:48:10 ******/
UPDATE STATISTICS [dbo].[ExpenseComposition]([PK__ExpenseC__AF91D0E1D8CFDC39]) WITH STATS_STREAM = ..., ROWCOUNT = 29, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_3B75D760]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_3B75D760]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000002_3B75D760] ON [dbo].[ExpenseIvoices]([IdСounterparties]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_3B75D760]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_3B75D760]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000003_3B75D760] ON [dbo].[ExpenseIvoices]([IdEmployee]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000005_3B75D760]

-- %%
/****** Object:  Statistic [_WA_Sys_00000005_3B75D760]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000005_3B75D760] ON [dbo].[ExpenseIvoices]([DistributedInvoice]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__ExpenseI__17193BDF5EAB38DD]

-- %%
/****** Object:  Statistic [PK__ExpenseI__17193BDF5EAB38DD]    Script Date: 10.12.2023 15:48:10 ******/
UPDATE STATISTICS [dbo].[ExpenseIvoices]([PK__ExpenseI__17193BDF5EAB38DD]) WITH STATS_STREAM = ..., ROWCOUNT = 12, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_34C8D9D1]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_34C8D9D1]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000002_34C8D9D1] ON [dbo].[TypesEmployee]([Nazv_type]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__TypesEmp__168EF03C2C9D8F19]

-- %%
/****** Object:  Statistic [PK__TypesEmp__168EF03C2C9D8F19]    Script Date: 10.12.2023 15:48:10 ******/
UPDATE STATISTICS [dbo].[TypesEmployee]([PK__TypesEmp__168EF03C2C9D8F19]) WITH STATS_STREAM = ..., ROWCOUNT = 3, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [_WA_Sys_00000002_398D8EEE]

-- %%
/****** Object:  Statistic [_WA_Sys_00000002_398D8EEE]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000002_398D8EEE] ON [dbo].[Сounterparties]([Nazv_Сounterparties]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000003_398D8EEE]

-- %%
/****** Object:  Statistic [_WA_Sys_00000003_398D8EEE]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000003_398D8EEE] ON [dbo].[Сounterparties]([INN]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [_WA_Sys_00000004_398D8EEE]

-- %%
/****** Object:  Statistic [_WA_Sys_00000004_398D8EEE]    Script Date: 10.12.2023 15:48:10 ******/
CREATE STATISTICS [_WA_Sys_00000004_398D8EEE] ON [dbo].[Сounterparties]([Adress_Сounterparties]) WITH STATS_STREAM = ...
GO

-- %% [markdown]
-- # [PK__Сounterp__E5F6AB5E0218DA8B]

-- %%
/****** Object:  Statistic [PK__Сounterp__E5F6AB5E0218DA8B]    Script Date: 10.12.2023 15:48:10 ******/
UPDATE STATISTICS [dbo].[Сounterparties]([PK__Сounterp__E5F6AB5E0218DA8B]) WITH STATS_STREAM = ..., ROWCOUNT = 8, PAGECOUNT = 1
GO

-- %% [markdown]
-- # [SalesOfMaterial]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [SalesOfMaterial] SET  READ_WRITE 
GO
